# %%
import sys
import cv2
import copy

# %%
# 배경 리스트 background[]
background = ['.\\image2\\background\\orange.png',
              '.\\image2\\background\\yellow.png',
              '.\\image2\\background\\green.png',
              '.\\image2\\background\\purple.png',
              '.\\image2\\background\\gray.png']

# 접시 리스트 dish[]
dish = ['.\\image2\\dish\\red.png',
        '.\\image2\\dish\\yellow.png',
        '.\\image2\\dish\\blue.png',
        '.\\image2\\dish\\black.png']

# 생선 리스트 fish[]
fish = ['.\\image2\\fish\\flatfish.png',
        '.\\image2\\fish\\salmon.png',
        '.\\image2\\fish\\tuna.png',
        '.\\image2\\fish\\shrimp.png']

# 효과 리스트 effect[]
effect = ['.\\image2\\effect\\good.png',
          '.\\image2\\effect\\star.png',
          '.\\image2\\effect\\heart.png',
          '.\\image2\\effect\\skeleton.png']

# %%
# NFT 대량 생산을 위한 반복문 
background_len = len(background)
dish_len = len(dish)
fish_len = len(fish)
effect_len = len(effect)
nft_len = background_len * dish_len * fish_len * effect_len

print(background_len)
print(dish_len)
print(fish_len)
print(effect_len)
print(nft_len)
# Out:
# 5
# 4
# 4
# 4
# 320

# %%
nft_count = 1
for i in range(0, background_len) : 
    
    background = cv2.imread(background[i], cv2.IMREAD_COLOR)
    if background is None :
        print('background read error!')
        sys.exit() 
              
    for j in range(0, dish_len) :
        
        dish_src = cv2.imread(dish[j], cv2.IMREAD_COLOR)
        dish_mask = cv2.imread(dish[j], cv2.IMREAD_GRAYSCALE)
        if dish_src is None or dish_mask is None :
            print('dish read error!')
            sys.exit()    
                    
        for k in range(0, fish_len) :

            fish_src = cv2.imread(fish[k], cv2.IMREAD_COLOR)
            fish_mask = cv2.imread(fish[k], cv2.IMREAD_GRAYSCALE)
            if fish_src is None or fish_mask is None :
                print('fish read error!')
                sys.exit()
                
            for l in range(0, effect_len) :
                
                effect_src = cv2.imread(effect[l], cv2.IMREAD_COLOR)
                effect_mask = cv2.imread(effect[l], cv2.IMREAD_GRAYSCALE)
                if effect_src is None or effect_mask is None :
                    print('effect read error!')
                    sys.exit()
                
                nft = copy.deepcopy(background)
                nft[dish_mask > 0] = dish_src[dish_mask > 0]
                nft[fish_mask > 0] = fish_src[fish_mask > 0]
                nft[effect_mask > 0] = effect_src[effect_mask > 0]
                    
                file_name = '.\\nft_generated\\NFT'+str(nft_count)+'.png'
                print(file_name+"\n")
                cv2.imwrite(file_name, nft)
                nft_count += 1
# Out:
# .\nft_generated\NFT1.png
#
# .\nft_generated\NFT2.png
#
# .\nft_generated\NFT3.png
#
# .\nft_generated\NFT4.png
#
# .\nft_generated\NFT5.png
#
# .\nft_generated\NFT6.png
#
# .\nft_generated\NFT7.png
#
# .\nft_generated\NFT8.png
#
# .\nft_generated\NFT9.png
#
# .\nft_generated\NFT10.png
#
# .\nft_generated\NFT11.png
#
# .\nft_generated\NFT12.png
#
# .\nft_generated\NFT13.png
#
# .\nft_generated\NFT14.png
#
# .\nft_generated\NFT15.png
#
# .\nft_generated\NFT16.png
#
# .\nft_generated\NFT17.png
#
# .\nft_generated\NFT18.png
#
# .\nft_generated\NFT19.png
#
# .\nft_generated\NFT20.png
#
# .\nft_generated\NFT21.png
#
# .\nft_generated\NFT22.png
#
# .\nft_generated\NFT23.png
#
# .\nft_generated\NFT24.png
#
# .\nft_generated\NFT25.png
#
# .\nft_generated\NFT26.png
#
# .\nft_generated\NFT27.png
#
# .\nft_generated\NFT28.png
#
# .\nft_generated\NFT29.png
#
# .\nft_generated\NFT30.png
#
# .\nft_generated\NFT31.png
#
# .\nft_generated\NFT32.png
#
# .\nft_generated\NFT33.png
#
# .\nft_generated\NFT34.png
#
# .\nft_generated\NFT35.png
#
# .\nft_generated\NFT36.png
#
# .\nft_generated\NFT37.png
#
# .\nft_generated\NFT38.png
#
# .\nft_generated\NFT39.png
#
# .\nft_generated\NFT40.png
#
# .\nft_generated\NFT41.png
#
# .\nft_generated\NFT42.png
#
# .\nft_generated\NFT43.png
#
# .\nft_generated\NFT44.png
#
# .\nft_generated\NFT45.png
#
# .\nft_generated\NFT46.png
#
# .\nft_generated\NFT47.png
#
# .\nft_generated\NFT48.png
#
# .\nft_generated\NFT49.png
#
# .\nft_generated\NFT50.png
#
# .\nft_generated\NFT51.png
#
# .\nft_generated\NFT52.png
#
# .\nft_generated\NFT53.png
#
# .\nft_generated\NFT54.png
#
# .\nft_generated\NFT55.png
#
# .\nft_generated\NFT56.png
#
# .\nft_generated\NFT57.png
#
# .\nft_generated\NFT58.png
#
# .\nft_generated\NFT59.png
#
# .\nft_generated\NFT60.png
#
# .\nft_generated\NFT61.png
#
# .\nft_generated\NFT62.png
#
# .\nft_generated\NFT63.png
#
# .\nft_generated\NFT64.png
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\OpenCV\OpenCV_NFT_generator\nft_generator.ipynb Cell 4' in <module>
#       <a href='vscode-notebook-cell:/d%3A/OpenCV/OpenCV_NFT_generator/nft_generator.ipynb#ch0000003?line=0'>1</a> nft_count = 1
#       <a href='vscode-notebook-cell:/d%3A/OpenCV/OpenCV_NFT_generator/nft_generator.ipynb#ch0000003?line=1'>2</a> for i in range(0, background_len) :
# ----> <a href='vscode-notebook-cell:/d%3A/OpenCV/OpenCV_NFT_generator/nft_generator.ipynb#ch0000003?line=3'>4</a>     background = cv2.imread(background[i], cv2.IMREAD_COLOR)
#       <a href='vscode-notebook-cell:/d%3A/OpenCV/OpenCV_NFT_generator/nft_generator.ipynb#ch0000003?line=4'>5</a>     if background is None :
#       <a href='vscode-notebook-cell:/d%3A/OpenCV/OpenCV_NFT_generator/nft_generator.ipynb#ch0000003?line=5'>6</a>         print('background read error!')
#
# TypeError: Can't convert object to 'str' for 'filename'
